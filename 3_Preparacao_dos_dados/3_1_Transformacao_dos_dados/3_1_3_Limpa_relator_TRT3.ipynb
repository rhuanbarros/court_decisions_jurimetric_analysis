# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
import pandas as pd
import time

# %%
df = pd.read_csv( ".//Datasets_transformados_final//TRT3//TRT3_acordaos_amostra_2017_2018_2019_completo_com_indice.csv", encoding='utf-8' )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10875 entries, 0 to 10874
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INDEX            10875 non-null  int64
#  1   INTEIRO_TEOR     10875 non-null  object
#  2   DATA             10875 non-null  object
#  3   RELATOR          10875 non-null  object
#  4   ORGAO            10875 non-null  object
#  5   RECORRENTE       10875 non-null  object
#  6   DISPOSITIVO      10875 non-null  object
#  7   QTD_RECORRENTES  10875 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 679.8+ KB

# %%
df["RELATOR"].unique()
# Out:
# array(['Lucas Vanucci Lins', 'Convocado Delane Marcolino Ferreira',
#        'Marcelo Lamego Pertence',
#        'Convocada Maria Cristina Diniz Caixeta',
#        'Convocada Olivia Figueiredo Pinto Coelho',
#        'Luiz Antonio de Paula Iennaco', 'Rodrigo Ribeiro Bueno',
#        'Convocado Danilo Siqueira de C.Faria',
#        'Fernando Antonio Viegas Peixoto', 'Maria Lucia Cardoso Magalhaes',
#        'Sebastiao Geraldo de Oliveira', 'Ana Maria Amorim Reboucas',
#        'Jose Marlon de Freitas', 'Convocada Angela C.Rogedo Ribeiro',
#        'Emilia Facchini', 'Paulo Mauricio R. Pires',
#        'Jorge Berg de Mendonca', 'Luiz Otavio Linhares Renault',
#        'Camilla G.Pereira Zeidler', 'Convocado Ricardo Marcelo Silva',
#        'Convocada Luciana Alves Viotti', 'Marcio Ribeiro do Valle',
#        'Sercio da Silva Pecanha', 'Convocada Ana Maria Espi Cavalcanti',
#        'Paula Oliveira Cantelli', 'Maria Laura Franco Lima de Faria',
# ...

# %%
df["RELATOR"].value_counts()
# Out:
# Luiz Otavio Linhares Renault                                                                                                                                         236
# Convocado Danilo Siqueira de C.Faria                                                                                                                                 223
# Juliana Vignoli Cordeiro                                                                                                                                             217
# Maria Stela Alvares da S.Campos                                                                                                                                      216
# Manoel Barbosa da Silva                                                                                                                                              209
# ...

# %%
len( df["RELATOR"].unique() )
# Out:
# 647

# %%
coluna = df.RELATOR.str.replace("Convocado", "")
coluna = coluna.str.replace("Convocada", "")
coluna = coluna.str.split('Tema:').str[0]
coluna = coluna.str.strip()

# %%
coluna.unique()
# Out:
# array(['Lucas Vanucci Lins', 'Delane Marcolino Ferreira',
#        'Marcelo Lamego Pertence', 'Maria Cristina Diniz Caixeta',
#        'Olivia Figueiredo Pinto Coelho', 'Luiz Antonio de Paula Iennaco',
#        'Rodrigo Ribeiro Bueno', 'Danilo Siqueira de C.Faria',
#        'Fernando Antonio Viegas Peixoto', 'Maria Lucia Cardoso Magalhaes',
#        'Sebastiao Geraldo de Oliveira', 'Ana Maria Amorim Reboucas',
#        'Jose Marlon de Freitas', 'Angela C.Rogedo Ribeiro',
#        'Emilia Facchini', 'Paulo Mauricio R. Pires',
#        'Jorge Berg de Mendonca', 'Luiz Otavio Linhares Renault',
#        'Camilla G.Pereira Zeidler', 'Ricardo Marcelo Silva',
#        'Luciana Alves Viotti', 'Marcio Ribeiro do Valle',
#        'Sercio da Silva Pecanha', 'Ana Maria Espi Cavalcanti',
#        'Paula Oliveira Cantelli', 'Maria Laura Franco Lima de Faria',
#        'Jales Valadao Cardoso', 'Carlos Roberto Barbosa',
#        'Emerson Jose Alves Lage', 'Cristiana M.Valadares Fenelon',
# ...

# %%
len( coluna.unique() )
# Out:
# 87

# %%
coluna.value_counts()
# Out:
# Luiz Otavio Linhares Renault       255
# Juliana Vignoli Cordeiro           231
# Danilo Siqueira de C.Faria         229
# Joao Bosco Pinto Lara              225
# Maria Stela Alvares da S.Campos    221
#                                   ...
# Leonardo Passos Ferreira            16
# Cristina Adelaide Custodio           9
# Flavio Vilson da Silva Barbosa       8
# Paulo Emilio Vilhena da Silva        6
# Erica Aparecida Pires Bessa          5
# Name: RELATOR, Length: 87, dtype: int64

# %%
len( coluna )
# Out:
# 10875

# %%
df["RELATOR"] = coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10875 entries, 0 to 10874
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   INDEX            10875 non-null  int64
#  1   INTEIRO_TEOR     10875 non-null  object
#  2   DATA             10875 non-null  object
#  3   RELATOR          10875 non-null  object
#  4   ORGAO            10875 non-null  object
#  5   RECORRENTE       10875 non-null  object
#  6   DISPOSITIVO      10875 non-null  object
#  7   QTD_RECORRENTES  10875 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 679.8+ KB

# %%
df["RELATOR"].value_counts()
# Out:
# Luiz Otavio Linhares Renault       255
# Juliana Vignoli Cordeiro           231
# Danilo Siqueira de C.Faria         229
# Joao Bosco Pinto Lara              225
# Maria Stela Alvares da S.Campos    221
#                                   ...
# Leonardo Passos Ferreira            16
# Cristina Adelaide Custodio           9
# Flavio Vilson da Silva Barbosa       8
# Paulo Emilio Vilhena da Silva        6
# Erica Aparecida Pires Bessa          5
# Name: RELATOR, Length: 87, dtype: int64

# %%
df.to_csv( ".//Datasets_transformados_final//TRT3//TRT3_acordaos_amostra_2017_2018_2019_completo_com_indice_relator_limpo.csv", encoding='utf-8', index=False )
