# %% [markdown]
# # Descricao e exploração dos dados

# %%
import pandas as pd

# %%
df = pd.read_csv( "..\\2_1_coleta_de_dados\\Datasets_coletados\\TRT4_inteiro_teor_2017_2018_2019_amostra.csv", encoding='utf-8' )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29893 entries, 0 to 29892
# Data columns (total 2 columns):
# LINK            29892 non-null object
# INTEIRO_TEOR    29893 non-null object
# dtypes: object(2)
# memory usage: 467.2+ KB

# %% [markdown]
# ### Conferindo datasets carregados

# %%
#aumenta o tamanho de exibição para poder ler o texto do dispositivo do acórdão
pd.set_option('display.max_colwidth', 100000)
pd.set_option('display.max_rows', 10)

# %%
df.sample(3, random_state=1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...

# %% [markdown]
# ### Preparação dos dados

# %%
df['NUM_CARACTERES'] = df['INTEIRO_TEOR'].astype(str).apply(len)
df['NUM_PALAVRAS'] = df['INTEIRO_TEOR'].apply(lambda x: len(str(x).split()))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29893 entries, 0 to 29892
# Data columns (total 4 columns):
# LINK              29892 non-null object
# INTEIRO_TEOR      29893 non-null object
# NUM_CARACTERES    29893 non-null int64
# NUM_PALAVRAS      29893 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 934.3+ KB

# %%
import plotly.graph_objects as go

fig = go.Figure( )

fig.add_trace(go.Histogram(
    x=df["NUM_CARACTERES"],
    name="TRT 3ª Região",
    marker_color='#EB89B5',
    nbinsx=25 ))

# Overlay both histograms
fig.update_layout(
    title='Histograma quantidade de caracteres nos acórdãos do tribunal',
    xaxis_title_text='Quantidade de caracteres',
    yaxis_title_text='Quantidade de documentos',
    bargap=0.2,
    bargroupgap=0.1
    )
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure( )

fig.add_trace(go.Histogram(
    x=df["NUM_PALAVRAS"],
    name="TRT 3ª Região",
    marker_color='#EB89B5',
    nbinsx=25 ))

# Overlay both histograms
fig.update_layout(
    title='Histograma quantidade de palavras nos acórdãos do tribunal',
    xaxis_title_text='Quantidade de caracteres',
    yaxis_title_text='Quantidade de documentos',
    bargap=0.2,
    bargroupgap=0.1
    )
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()

# %%
df.describe()
# Out:
#        NUM_CARACTERES  NUM_PALAVRAS
# count    29893.000000  29893.000000
# mean     17926.647911   2738.166828
# std      15071.879065   2357.615909
# min          3.000000      0.000000
# 25%       7137.000000   1051.000000
# 50%      13639.000000   2065.000000
# 75%      23805.000000   3654.000000
# max     151415.000000  23391.000000

# %% [markdown]
# ## Visualiza documentos com poucas palavras

# %% [markdown]
# #### É possível observar que há documentos OK em amostras com até 200 palavras

# %%
df.loc[ df["NUM_PALAVRAS"] < 200, "INTEIRO_TEOR" ]
# Out:
# 56                                                                                                                                                     Acórdão: 0020484-24.2018.5.04.0372 ( RORSum )   Redator: ALEXANDRE CORREA DA CRUZ    Órgão julgador:  3ª Turma    Data:  18/03/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020484-24.2018.5.04.0372 (ROPS) RECORRENTE: VERCELLI INDUSTRIA E COMERCIO DE CALCADOS EIRELI RECORRIDO: ELISABETE RODRIGUES MACHADO RELATOR: ALEXANDRE CORREA DA CRUZ          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 3ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade de votos, negar provimento ao recurso ordinário da reclamada, mantendo a sentença recorrida, por seus jurídicos e legais fundamentos, nos termos do art. 895, parágrafo primeiro, inciso IV, "in fine", da CLT, com a redação dada pela Lei número 9.957, de 12.01.2000. Intimem-se.   Intime-se.  Porto Alegre, 11 de março de 2019 (segunda-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       ALEXANDRE CORREA DA CRUZ Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR ALEXANDRE CORRÊA DA CRUZ (RELATOR)  DESEMBARGADOR CLÓVIS FERNANDO SCHUCH SANTOS  JUIZ CONVOCADO LUIS CARLOS PINTO GASTAL
# 78                                                                                                                                                                              Acórdão: 0021648-18.2016.5.04.0332 ( RORSum )   Redator: IRIS LIMA DE MORAES    Órgão julgador:  1ª Turma    Data:  18/10/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0021648-18.2016.5.04.0332 (ROPS) RECORRENTE: CRISTIELE VALANEIRA DA SILVA RECORRIDO: PRATO FEITO - ALIMENTACAO E SERVICOS LTDA, FORJAS TAURUS SA RELATOR: IRIS LIMA DE MORAES          EMENTA          PROCEDIMENTO SUMARÍSSIMO.             ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 1ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO ORDINÁRIO DA RECLAMANTE (CRISTIELE VALANEIRA DA SILVA); Mantém-se a sentença por seus próprios fundamentos, nos termos do artigo 895, §º 1º, inciso IV, "in fine", da CLT.  Intime-se.  Porto Alegre, 18 de outubro de 2017 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         PROCEDIMENTO SUMARÍSSIMO.     É o relatório.          FUNDAMENTAÇÃO                  Assinatura       IRIS LIMA DE MORAES Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA IRIS LIMA DE MORAES (RELATORA)  DESEMBARGADORA ROSANE SERAFINI CASA NOVA  DESEMBARGADORA LAÍS HELENA JAEGER NICOTTI
# 88           Acórdão: 0021056-75.2017.5.04.0772 ( RORSum )   Redator: LAIS HELENA JAEGER NICOTTI    Órgão julgador:  1ª Turma    Data:  16/05/2018          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0021056-75.2017.5.04.0772 (ROPS) RECORRENTE: CLARICE PEREIRA LOPES RECORRIDO: ECONOBLE SERVICOS E SOLUCOES INTEGRADAS LTDA, SERVICO NACIONAL DE APRENDIZAGEM COMERCIAL SENAC AR/RS RELATOR: LAIS HELENA JAEGER NICOTTI          EMENTA          PROCEDIMENTO SUMARÍSSIMO            ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 1ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO ORDINÁRIO DO SEGUNDO RECLAMADO , Serviço Nacional de Aprendizagem Comercial - SENAC AR/RS , mantendo a decisão recorrida por seus próprios e jurídicos fundamentos, nos termos do artigo 895, § 1º, inciso IV, in fine , da CLT, com a redação dada pela Lei nº 9.957/2000.  Intime-se.  Porto Alegre, 16 de maio de 2018 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         PROCEDIMENTO SUMARÍSSIMO    É o relatório.          FUNDAMENTAÇÃO         PROCEDIMENTO SUMARÍSSIMO            Assinatura       LAIS HELENA JAEGER NICOTTI Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA LAÍS HELENA JAEGER NICOTTI (RELATORA)  DESEMBARGADOR MANUEL CID JARDON  DESEMBARGADOR FABIANO HOLZ BESERRA
# 126                                                                                                                                                                                                                                                                                              Acórdão: 0020073-52.2019.5.04.0531 ( RORSum )   Redator: GILBERTO SOUZA DOS SANTOS    Órgão julgador:  8ª Turma    Data:  26/08/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020073-52.2019.5.04.0531 (ROPS) RECORRENTE: ANA CARINA RODRIGUES DE RODRIGUES RECORRIDO: CENTRO DE RECREACAO & APRENDIZAGEM BEM-ME-QUER LTDA - ME RELATOR: GILBERTO SOUZA DOS SANTOS          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 8ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DA AUTORA , para manter a sentença por seu próprios fundamentos, na forma do art. 895, IV, da CLT.  Intime-se.  Porto Alegre, 07 de agosto de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       GILBERTO SOUZA DOS SANTOS Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR GILBERTO SOUZA DOS SANTOS (RELATOR)  DESEMBARGADOR FRANCISCO ROSSAL DE ARAÚJO  DESEMBARGADOR LUIZ ALBERTO DE VARGAS
# 163                                                                                                                                                                                                                          Acórdão: 0020822-29.2018.5.04.0006 ( RORSum )   Redator: CLOVIS FERNANDO SCHUCH SANTOS    Órgão julgador:  3ª Turma    Data:  15/05/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020822-29.2018.5.04.0006 (ROPS) RECORRENTE: DANIELA DUTRA FAGUNDES RECORRIDO: HOSPITAL NOSSA SENHORA DA CONCEICAO SA RELATOR: CLOVIS FERNANDO SCHUCH SANTOS          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 3ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade de votos, negar provimento ao recurso da parte ré, Hospital Nossa Senhora da Conceição S.A,  mantendo-se a sentença por seus próprios e jurídicos fundamentos, nos termos do artigo 895, §1º, inciso IV, da CLT.   Intime-se.  Porto Alegre, 06 de maio de 2019 (segunda-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       CLOVIS FERNANDO SCHUCH SANTOS Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR CLÓVIS FERNANDO SCHUCH SANTOS (RELATOR)  DESEMBARGADORA MARIA MADALENA TELESCA  JUIZ CONVOCADO LUIS CARLOS PINTO GASTAL
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 29681                                                                                                                                                                                                                                                                                                                                                                           Acórdão: 0020083-25.2019.5.04.0005 ( RORSum )   Redator: BEATRIZ RENCK    Órgão julgador:  6ª Turma    Data:  24/10/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020083-25.2019.5.04.0005 (RORSum) RECORRENTE: ALEXSANDRO DA SILVA SEIDENKRANZ RECORRIDO: PORTO SHOP S.A. RELATOR: BEATRIZ RENCK          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 6ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, negar provimento ao recurso do autor e manter a sentença pelos próprios fundamentos nos termos do inc. IV do § 1º do art. 895 da CLT.  Intime-se.  Porto Alegre, 23 de outubro de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       BEATRIZ RENCK Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA BEATRIZ RENCK (RELATORA)  JUIZ CONVOCADO EDSON PECIS LERRER  DESEMBARGADOR FERNANDO LUIZ DE MOURA CASSAL
# 29748                                                                                                                                                                                                                                                                       Acórdão: 0020700-56.2018.5.04.0025 ( RORSum )   Redator: EDSON PECIS LERRER    Órgão julgador:  6ª Turma    Data:  03/10/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO               Identificação        PROCESSO nº 0020700-56.2018.5.04.0025 (RORSum) RECORRENTE: THIAGO DA SILVEIRA TEIXEIRA RECORRIDO: ADMINISTRADORA E SERVICOS EM CONDOMINIO DE SEGURANCA E LIMPEZA P&G LTDA, ATLAS MG NEGOCIOS IMOBILIARIOS LTDA, CONDOMÍNIO RESIDENCIAL CAMAQUÃ RELATOR: EDSON PECIS LERRER                        CERTIDÃO DE JULGAMENTO        Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 6ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DO RECLAMANTE , confirmando a sentença por seus próprios fundamentos (art. 895, §1º, IV, da CLT).  Intime-se.  Porto Alegre, 02 de outubro de 2019 (quarta-feira).          Cabeçalho do acórdão              Acórdão                                        Assinatura       EDSON PECIS LERRER Relator           VOTOS          PARTICIPARAM DO JULGAMENTO:  JUIZ CONVOCADO EDSON PECIS LERRER (RELATOR)  DESEMBARGADOR FERNANDO LUIZ DE MOURA CASSAL  DESEMBARGADORA MARIA CRISTINA SCHAAN FERREIRA
# 29756                                                                                                                                                                                                                                                                                                                                                                                                                        Acórdão: 0021346-27.2016.5.04.0772 ( RORSum )   Redator: FABIANO HOLZ BESERRA    Órgão julgador:  1ª Turma    Data:  08/05/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO               Identificação        PROCESSO nº 0021346-27.2016.5.04.0772 (ROPS) RECORRENTE: BRF S.A. RECORRIDO: ALEXSANDRA PAIM DA SILVA RELATOR: FABIANO HOLZ BESERRA                             Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 1ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DA RECLAMADA , mantendo a sentença pelos seus próprios fundamentos, na forma do art. 895, § 1º, inciso IV, da CLT.  Intime-se.  Porto Alegre, 04 de maio de 2017 (quinta-feira).          Cabeçalho do acórdão               Acórdão                    É o relatório.                       Assinatura       FABIANO HOLZ BESERRA Relator                  PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR FABIANO HOLZ BESERRA (RELATOR)  DESEMBARGADORA IRIS LIMA DE MORAES  DESEMBARGADORA ROSANE SERAFINI CASA NOVA
# 29760                                                                                                                                                                                                                                                                                              Acórdão: 0021037-75.2018.5.04.0403 ( RORSum )   Redator: ROSANE SERAFINI CASA NOVA    Órgão julgador:  1ª Turma    Data:  27/06/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO               Identificação        PROCESSO nº 0021037-75.2018.5.04.0403 (ROPS) RECORRENTE: CLARO S.A. RECORRIDO: ARIEL PAULO DAL RI, VAHR - CONSULTORIA E TERCEIRIZACAO EM TECNOLOGIA LTDA RELATOR: ROSANE SERAFINI CASA NOVA           EMENTA           PROCEDIMENTO SUMARÍSSIMO              ACÓRDÃO          Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 1ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO ORDINÁRIO DA RECLAMADA CLARO S.A. .  Intime-se.  Porto Alegre, 26 de junho de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO          PROCEDIMENTO SUMARÍSSIMO    É o relatório.           FUNDAMENTAÇÃO                   Assinatura       ROSANE SERAFINI CASA NOVA Relator           VOTOS            PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA ROSANE SERAFINI CASA NOVA (RELATORA)  DESEMBARGADOR FABIANO HOLZ BESERRA  DESEMBARGADORA LAÍS HELENA JAEGER NICOTTI
# 29787                                                                                                                                                                              Acórdão: 0021769-43.2015.5.04.0021 ( ROT )   Redator: CLOVIS FERNANDO SCHUCH SANTOS    Órgão julgador:  5ª Turma    Data:  24/03/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0021769-43.2015.5.04.0021 (ROPS) RECORRENTE: PETROBRAS DISTRIBUIDORA S A RECORRIDO: LUCAS ALBERTO ROSSI DE OLIVEIRA, MV TRETTON SERVICOS E COMERCIO EIRELI RELATOR: CLOVIS FERNANDO SCHUCH SANTOS          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 5ª Turma do Tribunal Regional do Trabalho da 4ª Região: à unanimidade de votos, negar provimento ao recurso ordinário da reclamada, Petrobrás Distribuidora S.A., mantendo-se a sentença, por seus próprios fundamentos, com base no disposto no art.  895, §1º, inciso IV, da CLT.   Intime-se.  Porto Alegre, 16 de março de 2017 (quinta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       CLOVIS FERNANDO SCHUCH SANTOS Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR CLÓVIS FERNANDO SCHUCH SANTOS (RELATOR)  DESEMBARGADORA BRÍGIDA JOAQUINA CHARÃO BARCELOS TOSCHI  DESEMBARGADORA KARINA SARAIVA CUNHA
# Name: INTEIRO_TEOR, Length: 531, dtype: object

# %% [markdown]
# #### É possível observar que abaixo de 150 palavras há documentos incorretos, ou seja, fora dos padrões de qualidade

# %%
df.loc[ df["NUM_PALAVRAS"] < 150, "INTEIRO_TEOR" ]
# Out:
# 126                                           Acórdão: 0020073-52.2019.5.04.0531 ( RORSum )   Redator: GILBERTO SOUZA DOS SANTOS    Órgão julgador:  8ª Turma    Data:  26/08/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020073-52.2019.5.04.0531 (ROPS) RECORRENTE: ANA CARINA RODRIGUES DE RODRIGUES RECORRIDO: CENTRO DE RECREACAO & APRENDIZAGEM BEM-ME-QUER LTDA - ME RELATOR: GILBERTO SOUZA DOS SANTOS          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 8ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DA AUTORA , para manter a sentença por seu próprios fundamentos, na forma do art. 895, IV, da CLT.  Intime-se.  Porto Alegre, 07 de agosto de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       GILBERTO SOUZA DOS SANTOS Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR GILBERTO SOUZA DOS SANTOS (RELATOR)  DESEMBARGADOR FRANCISCO ROSSAL DE ARAÚJO  DESEMBARGADOR LUIZ ALBERTO DE VARGAS
# 195                                                Acórdão: 0020531-02.2018.5.04.0791 ( RORSum )   Redator: GEORGE ACHUTTI    Órgão julgador:  4ª Turma    Data:  16/05/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020531-02.2018.5.04.0791 (ROPS) RECORRENTE: FRANQUIELE GISLAINE DA SILVA RECORRIDO: CALCADOS BEIRA RIO S/A RELATOR: GEORGE ACHUTTI          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 4ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DA RECLAMANTE, FRANQUIELE GISLAINE DA SILVA, mantendo a decisão por seus próprios fundamentos, consoante art. 895, § 1º, inciso IV, da CLT, com redação outorgada pela Lei nº 9.957/2000.  Intime-se.  Porto Alegre, 15 de maio de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       GEORGE ACHUTTI Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR GEORGE ACHUTTI (RELATOR)  DESEMBARGADOR JOÃO PAULO LUCENA  DESEMBARGADOR ANDRÉ REVERBEL FERNANDES
# 540                                                                                       Acórdão: 0021507-35.2016.5.04.0029 ( RORSum )   Redator: HERBERT PAULO BECK    Órgão julgador:  11ª Turma    Data:  02/05/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0021507-35.2016.5.04.0029 (ROPS) RECORRENTE: LOJAS RENNER S.A. RECORRIDO: THAINA MARQUES CAMARGO RELATOR: HERBERT PAULO BECK          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 11ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO ORDINÁRIO DA RECLAMADA , mantendo a sentença pelos próprios fundamentos, nos termos do art. 895, § 1º, IV, da CLT.  Intime-se.  Porto Alegre, 27 de abril de 2017 (quinta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       HERBERT PAULO BECK Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR HERBERT PAULO BECK (RELATOR)  DESEMBARGADORA FLÁVIA LORENA PACHECO  DESEMBARGADOR RICARDO HOFMEISTER DE ALMEIDA MARTINS COSTA
# 705          Acórdão: 0020419-79.2017.5.04.0011 ( RORSum )   Redator: GEORGE ACHUTTI    Órgão julgador:  4ª Turma    Data:  21/09/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020419-79.2017.5.04.0011 (ROPS) RECORRENTE: LIDERANCA LIMPEZA E CONSERVACAO LTDA RECORRIDO: MAURICIO CHAVES RODRIGUES RELATOR: GEORGE ACHUTTI          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 4ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO ORDINÁRIO DA RECLAMADA, LIDERANÇA LIMPEZA E CONSERVAÇÃO LTDA., mantendo a sentença por seus próprios fundamentos, consoante art. 895, § 1º, inc. IV, da CLT, com redação outorgada pela Lei nº 9.957/2000.  Intime-se.  Porto Alegre, 19 de setembro de 2017 (terça-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       GEORGE ACHUTTI Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR GEORGE ACHUTTI (RELATOR)  DESEMBARGADOR ANDRÉ REVERBEL FERNANDES  DESEMBARGADORA ANA LUIZA HEINECK KRUSE
# 722                                   Acórdão: 0021041-36.2015.5.04.0333 ( RORSum )   Redator: LUIS CARLOS PINTO GASTAL    Órgão julgador:  3ª Turma    Data:  01/02/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0021041-36.2015.5.04.0333 (ROPS) RECORRENTE: CALCADOS BOTTERO LTDA RECORRIDO: VERANICE RAUBER CHAVES, ISOLDE FRANZEN FESTNER - ME, ATELIE FESTNER LTDA - EPP, G5 PRINT LTDA - ME, INDUSTRIA DE CALCADOS SOFT LTDA - EPP, CALCADOS BOTTERO LTDA RELATOR: LUIS CARLOS PINTO GASTAL          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 3ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DA QUINTA RECLAMADA.  Intime-se.  Porto Alegre, 31 de janeiro de 2017 (terça-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       LUIS CARLOS PINTO GASTAL Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  JUIZ CONVOCADO LUIS CARLOS PINTO GASTAL (RELATOR)  DESEMBARGADOR RICARDO CARVALHO FRAGA  DESEMBARGADORA MARIA MADALENA TELESCA
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 29610                                              Acórdão: 0020160-42.2017.5.04.0122 ( RORSum )   Redator: MARIA MADALENA TELESCA    Órgão julgador:  3ª Turma    Data:  27/10/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020160-42.2017.5.04.0122 (ROPS) RECORRENTE: CALMON MANUTENCAO E MONTAGENS LTDA - ME RECORRIDO: HELTON CASSIO DA SILVA SANTOS RELATOR: MARIA MADALENA TELESCA          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 3ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, negar provimento ao recurso da reclamada, mantendo-se a sentença por seus próprios fundamentos, nos termos do art. 895, § 1º, IV, segunda parte, da CLT.  Intime-se.  Porto Alegre, 25 de outubro de 2017 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       MARIA MADALENA TELESCA Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA MARIA MADALENA TELESCA (RELATORA)  DESEMBARGADOR GILBERTO SOUZA DOS SANTOS  DESEMBARGADOR RICARDO CARVALHO FRAGA
# 29681                                                                                                                        Acórdão: 0020083-25.2019.5.04.0005 ( RORSum )   Redator: BEATRIZ RENCK    Órgão julgador:  6ª Turma    Data:  24/10/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO              Identificação       PROCESSO nº 0020083-25.2019.5.04.0005 (RORSum) RECORRENTE: ALEXSANDRO DA SILVA SEIDENKRANZ RECORRIDO: PORTO SHOP S.A. RELATOR: BEATRIZ RENCK          EMENTA                   ACÓRDÃO         Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 6ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, negar provimento ao recurso do autor e manter a sentença pelos próprios fundamentos nos termos do inc. IV do § 1º do art. 895 da CLT.  Intime-se.  Porto Alegre, 23 de outubro de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO         É o relatório.          FUNDAMENTAÇÃO                  Assinatura       BEATRIZ RENCK Relator          VOTOS           PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA BEATRIZ RENCK (RELATORA)  JUIZ CONVOCADO EDSON PECIS LERRER  DESEMBARGADOR FERNANDO LUIZ DE MOURA CASSAL
# 29748                    Acórdão: 0020700-56.2018.5.04.0025 ( RORSum )   Redator: EDSON PECIS LERRER    Órgão julgador:  6ª Turma    Data:  03/10/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO               Identificação        PROCESSO nº 0020700-56.2018.5.04.0025 (RORSum) RECORRENTE: THIAGO DA SILVEIRA TEIXEIRA RECORRIDO: ADMINISTRADORA E SERVICOS EM CONDOMINIO DE SEGURANCA E LIMPEZA P&G LTDA, ATLAS MG NEGOCIOS IMOBILIARIOS LTDA, CONDOMÍNIO RESIDENCIAL CAMAQUÃ RELATOR: EDSON PECIS LERRER                        CERTIDÃO DE JULGAMENTO        Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 6ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DO RECLAMANTE , confirmando a sentença por seus próprios fundamentos (art. 895, §1º, IV, da CLT).  Intime-se.  Porto Alegre, 02 de outubro de 2019 (quarta-feira).          Cabeçalho do acórdão              Acórdão                                        Assinatura       EDSON PECIS LERRER Relator           VOTOS          PARTICIPARAM DO JULGAMENTO:  JUIZ CONVOCADO EDSON PECIS LERRER (RELATOR)  DESEMBARGADOR FERNANDO LUIZ DE MOURA CASSAL  DESEMBARGADORA MARIA CRISTINA SCHAAN FERREIRA
# 29756                                                                                                                                                                     Acórdão: 0021346-27.2016.5.04.0772 ( RORSum )   Redator: FABIANO HOLZ BESERRA    Órgão julgador:  1ª Turma    Data:  08/05/2017          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO               Identificação        PROCESSO nº 0021346-27.2016.5.04.0772 (ROPS) RECORRENTE: BRF S.A. RECORRIDO: ALEXSANDRA PAIM DA SILVA RELATOR: FABIANO HOLZ BESERRA                             Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 1ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO DA RECLAMADA , mantendo a sentença pelos seus próprios fundamentos, na forma do art. 895, § 1º, inciso IV, da CLT.  Intime-se.  Porto Alegre, 04 de maio de 2017 (quinta-feira).          Cabeçalho do acórdão               Acórdão                    É o relatório.                       Assinatura       FABIANO HOLZ BESERRA Relator                  PARTICIPARAM DO JULGAMENTO:  DESEMBARGADOR FABIANO HOLZ BESERRA (RELATOR)  DESEMBARGADORA IRIS LIMA DE MORAES  DESEMBARGADORA ROSANE SERAFINI CASA NOVA
# 29760                                           Acórdão: 0021037-75.2018.5.04.0403 ( RORSum )   Redator: ROSANE SERAFINI CASA NOVA    Órgão julgador:  1ª Turma    Data:  27/06/2019          PODER JUDICIÁRIO   JUSTIÇA DO TRABALHO   TRIBUNAL REGIONAL DO TRABALHO DA 4ª REGIÃO               Identificação        PROCESSO nº 0021037-75.2018.5.04.0403 (ROPS) RECORRENTE: CLARO S.A. RECORRIDO: ARIEL PAULO DAL RI, VAHR - CONSULTORIA E TERCEIRIZACAO EM TECNOLOGIA LTDA RELATOR: ROSANE SERAFINI CASA NOVA           EMENTA           PROCEDIMENTO SUMARÍSSIMO              ACÓRDÃO          Vistos, relatados e discutidos os autos.  ACORDAM os Magistrados integrantes da 1ª Turma do Tribunal Regional do Trabalho da 4ª Região: por unanimidade, NEGAR PROVIMENTO AO RECURSO ORDINÁRIO DA RECLAMADA CLARO S.A. .  Intime-se.  Porto Alegre, 26 de junho de 2019 (quarta-feira).          Cabeçalho do acórdão               Acórdão               RELATÓRIO          PROCEDIMENTO SUMARÍSSIMO    É o relatório.           FUNDAMENTAÇÃO                   Assinatura       ROSANE SERAFINI CASA NOVA Relator           VOTOS            PARTICIPARAM DO JULGAMENTO:  DESEMBARGADORA ROSANE SERAFINI CASA NOVA (RELATORA)  DESEMBARGADOR FABIANO HOLZ BESERRA  DESEMBARGADORA LAÍS HELENA JAEGER NICOTTI
# Name: INTEIRO_TEOR, Length: 257, dtype: object

# %% [markdown]
# ### Limpeza dos documentos incorretos

# %%
df = df.loc[ df["NUM_PALAVRAS"] > 150, : ]

# %% [markdown]
# ## Descrição dos dados coletados após limpeza

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29629 entries, 0 to 29892
# Data columns (total 4 columns):
# LINK              29629 non-null object
# INTEIRO_TEOR      29629 non-null object
# NUM_CARACTERES    29629 non-null int64
# NUM_PALAVRAS      29629 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        NUM_CARACTERES  NUM_PALAVRAS
# count    29629.000000  29629.000000
# mean     18075.820615   2761.346316
# std      15055.421326   2355.215204
# min       1183.000000    151.000000
# 25%       7265.000000   1073.000000
# 50%      13783.000000   2086.000000
# 75%      23958.000000   3677.000000
# max     151415.000000  23391.000000

# %% [markdown]
# ## Distribuição dos unigramas mais usadas antes de remover stop words

# %%
from sklearn.feature_extraction.text import CountVectorizer
from plotly.offline import iplot

def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_words(df['INTEIRO_TEOR'], 20)
df1 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df1
# Out:
#    INTEIRO_TEOR  QUANTIDADE
# 0            de     4065528
# 1            do     2219509
# 2            da     2175871
# 3           que     2004688
# 4            em     1173910
# ..          ...         ...
# 15   reclamante      449824
# 16           as      405082
# 17          dos      399166
# 18          das      331502
# 19         como      319314
#
# [20 rows x 2 columns]

# %%
trace = go.Bar(x=df1["INTEIRO_TEOR"], y=df1["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos unigramas mais usadas depois de remover stop words

# %%
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('portuguese')
stopwords[:10]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rhuan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um']

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer( stop_words = frozenset( stopwords ) ).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(df['INTEIRO_TEOR'], 30)
df2 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df2
# Out:
#    INTEIRO_TEOR  QUANTIDADE
# 0      trabalho      451463
# 1    reclamante      449824
# 2     reclamada      303815
# 3           art      295991
# 4         horas      277982
# ..          ...         ...
# 25     tribunal      132903
# 26    adicional      132832
# 27        valor      131606
# 28      jornada      130797
# 29       quanto      130660
#
# [30 rows x 2 columns]

# %%
trace = go.Bar(x=df2["INTEIRO_TEOR"], y=df2["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos bigramas mais usadas antes de remover stop words

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['INTEIRO_TEOR'], 30)
df3 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df3
# Out:
#          INTEIRO_TEOR  QUANTIDADE
# 0         do trabalho      203569
# 1              da clt      201427
# 2         de trabalho      187254
# 3              do tst      150686
# 4             que não      147554
# ..                ...         ...
# 25     que reclamante       69363
# 26         nos termos       69320
# 27        trabalho da       67680
# 28  tribunal regional       66554
# 29            no caso       65127
#
# [30 rows x 2 columns]

# %%
trace = go.Bar(x=df3["INTEIRO_TEOR"], y=df3["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos bigramas mais usadas depois de remover stop words

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer( stop_words = frozenset( stopwords ), ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['INTEIRO_TEOR'], 30)
df4 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df4
# Out:
#               INTEIRO_TEOR  QUANTIDADE
# 0             horas extras      145643
# 1        recurso ordinário      104305
# 2                4ª região       81540
# 3       provimento recurso       69939
# 4        tribunal regional       66555
# ..                     ...         ...
# 25  intervalo intrajornada       31357
# 26                  000 00       31306
# 27        poder judiciário       30824
# 28          órgão julgador       30690
# 29            danos morais       30303
#
# [30 rows x 2 columns]

# %%
trace = go.Bar(x=df4["INTEIRO_TEOR"], y=df4["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos trigramas mais usadas antes de remover stop words

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(df['INTEIRO_TEOR'], 20)
df5 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df5
# Out:
#                   INTEIRO_TEOR  QUANTIDADE
# 0                 da 4ª região       80653
# 1        provimento ao recurso       65354
# 2               do trabalho da       60769
# 3         regional do trabalho       60178
# 4         tribunal regional do       59490
# ..                         ...         ...
# 15                   da lei nº       35653
# 16  adicional de insalubridade       35611
# 17              do contrato de       33117
# 18        recurso ordinário do       30854
# 19        do tribunal regional       29577
#
# [20 rows x 2 columns]

# %%
trace = go.Bar(x=df5["INTEIRO_TEOR"], y=df5["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos trigramas mais usadas depois de remover stop words

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer( stop_words = frozenset( stopwords ), ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(df['INTEIRO_TEOR'], 20)
df6 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df6
# Out:
#                     INTEIRO_TEOR  QUANTIDADE
# 0     tribunal regional trabalho       59482
# 1             trabalho 4ª região       58403
# 2           regional trabalho 4ª       58033
# 3   provimento recurso ordinário       33822
# 4   recurso ordinário reclamante       29893
# ..                           ...         ...
# 15       feira cabeçalho acórdão       28290
# 16     cabeçalho acórdão acórdão       28281
# 17     identificação processo nº       28242
# 18     acórdão acórdão relatório       28226
# 19      acórdão vistos relatados       28216
#
# [20 rows x 2 columns]

# %%
trace = go.Bar(x=df6["INTEIRO_TEOR"], y=df6["QUANTIDADE"])
iplot({"data":[trace]})
