# %% [markdown]
# # Descricao e exploração dos dados

# %%
#conda install -c plotly plotly=4.14.3

# %%
import pandas as pd

# %%
df1 = pd.read_csv( "..\\2_1_coleta_de_dados\\Datasets_coletados\\TRT3\\TRT3_inteiro_teor_2017_2018_2019_amostra_1.csv", encoding='utf-8' )

# %%
df2 = pd.read_csv( "..\\2_1_coleta_de_dados\\Datasets_coletados\\TRT3\\TRT3_inteiro_teor_2017_2018_2019_amostra_2.csv", encoding='utf-8' )

# %%
print( df1.info() )
print( df2.info() )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17845 entries, 0 to 17844
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   INTEIRO_TEOR  17844 non-null  object
# dtypes: object(1)
# memory usage: 139.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8787 entries, 0 to 8786
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   INTEIRO_TEOR  8786 non-null   object
# dtypes: object(1)
# memory usage: 68.8+ KB
# None

# %%
df = df1
df = df.append( df2 )
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26632 entries, 0 to 8786
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   INTEIRO_TEOR  26630 non-null  object
# dtypes: object(1)
# memory usage: 416.1+ KB

# %% [markdown]
# ### Conferindo dataset carregado

# %%
#aumenta o tamanho de exibição para poder ler o texto do dispositivo do acórdão
pd.set_option('display.max_colwidth', 100000)
pd.set_option('display.max_rows', 10)

# %%
df.sample(3, random_state=1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...

# %% [markdown]
# ### Preparação dos dados

# %%
df['NUM_CARACTERES'] = df['INTEIRO_TEOR'].astype(str).apply(len)
df['NUM_PALAVRAS'] = df['INTEIRO_TEOR'].apply(lambda x: len(str(x).split()))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26632 entries, 0 to 8786
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INTEIRO_TEOR    26630 non-null  object
#  1   NUM_CARACTERES  26632 non-null  int64
#  2   NUM_PALAVRAS    26632 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 832.2+ KB

# %%
import plotly.graph_objects as go

fig = go.Figure( )

fig.add_trace(go.Histogram(
    x=df["NUM_CARACTERES"],
    name="TRT 3ª Região",
    marker_color='#EB89B5',
    nbinsx=25 ))

# Overlay both histograms
fig.update_layout(
    title='Histograma quantidade de caracteres nos acórdãos do tribunal',
    xaxis_title_text='Quantidade de caracteres',
    yaxis_title_text='Quantidade de documentos',
    bargap=0.2,
    bargroupgap=0.1
    )
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()

# %%
import plotly.graph_objects as go

fig = go.Figure( )

fig.add_trace(go.Histogram(
    x=df["NUM_PALAVRAS"],
    name="TRT 3ª Região",
    marker_color='#EB89B5',
    nbinsx=25 ))

# Overlay both histograms
fig.update_layout(
    title='Histograma quantidade de palavras nos acórdãos do tribunal',
    xaxis_title_text='Quantidade de caracteres',
    yaxis_title_text='Quantidade de documentos',
    bargap=0.2,
    bargroupgap=0.1
    )
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.75)
fig.show()

# %%
df.describe()
# Out:
#        NUM_CARACTERES  NUM_PALAVRAS
# count    26632.000000  26632.000000
# mean     13615.314171   2093.499362
# std      12348.380787   1936.179613
# min          3.000000      1.000000
# 25%       5421.000000    810.000000
# 50%       9577.500000   1457.500000
# 75%      17464.250000   2690.000000
# max     152013.000000  23625.000000

# %% [markdown]
# ## Visualiza documentos com poucas palavras

# %% [markdown]
# #### É possível observar que há documentos OK em amostras com até 200 palavras

# %%
df.loc[ df["NUM_PALAVRAS"] < 200, "INTEIRO_TEOR" ]
# Out:
# 118                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            NaN
# 3295                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Nenhum registro foi selecionado para exportação.
# 8205                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            408 Request Time-out Seu navegador nÃ£o enviou uma requisiÃ§Ã£o completa a tempo.
# Name: INTEIRO_TEOR, dtype: object

# %% [markdown]
# ### Limpeza dos documentos incorretos

# %%
df = df.loc[ df["NUM_PALAVRAS"] > 150, : ]

# %% [markdown]
# ## Descrição dos dados coletados após limpeza

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26625 entries, 0 to 8786
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   INTEIRO_TEOR    26625 non-null  object
#  1   NUM_CARACTERES  26625 non-null  int64
#  2   NUM_PALAVRAS    26625 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 832.0+ KB

# %%
df.describe()
# Out:
#        NUM_CARACTERES  NUM_PALAVRAS
# count    26625.000000  26625.000000
# mean     13618.852131   2094.044394
# std      12348.075257   1936.142225
# min       1254.000000    157.000000
# 25%       5424.000000    810.000000
# 50%       9581.000000   1458.000000
# 75%      17468.000000   2691.000000
# max     152013.000000  23625.000000

# %% [markdown]
# ## Distribuição dos unigramas mais usadas antes de remover stop words

# %%
from sklearn.feature_extraction.text import CountVectorizer
from plotly.offline import iplot

def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

common_words = get_top_n_words(df['INTEIRO_TEOR'], 20)
df1 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df1
# Out:
#    INTEIRO_TEOR  QUANTIDADE
# 0            de     2775350
# 1            do     1547127
# 2            da     1473064
# 3           que     1255547
# 4            em      770191
# ..          ...         ...
# 15          com      314706
# 16   reclamante      267339
# 17           as      252065
# 18         pela      232139
# 19           id      229353
#
# [20 rows x 2 columns]

# %%
trace = go.Bar(x=df1["INTEIRO_TEOR"], y=df1["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos unigramas mais usadas depois de remover stop words

# %%
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('portuguese')
stopwords[:10]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rhuan\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um']

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer( stop_words = frozenset( stopwords ) ).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(df['INTEIRO_TEOR'], 30)
df2 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df2
# Out:
#    INTEIRO_TEOR  QUANTIDADE
# 0      trabalho      334005
# 1    reclamante      267339
# 2            id      229353
# 3           art      211333
# 4       recurso      200110
# ..          ...         ...
# 25      relator       93346
# 26     tribunal       90956
# 27     sentença       90608
# 28       mérito       89232
# 29       súmula       84152
#
# [30 rows x 2 columns]

# %%
trace = go.Bar(x=df2["INTEIRO_TEOR"], y=df2["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos bigramas mais usadas antes de remover stop words

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['INTEIRO_TEOR'], 30)
df3 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df3
# Out:
#     INTEIRO_TEOR  QUANTIDADE
# 0    do trabalho      197626
# 1         da clt      129891
# 2    de trabalho      106684
# 3   horas extras       89744
# 4        que não       88449
# ..           ...         ...
# 25    justiça do       42715
# 26      de horas       42659
# 27        não há       41766
# 28  da reclamada       39445
# 29   contrato de       37731
#
# [30 rows x 2 columns]

# %%
trace = go.Bar(x=df3["INTEIRO_TEOR"], y=df3["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos bigramas mais usadas depois de remover stop words

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer( stop_words = frozenset( stopwords ), ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(df['INTEIRO_TEOR'], 30)
df4 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df4
# Out:
#             INTEIRO_TEOR  QUANTIDADE
# 0           horas extras       90408
# 1      tribunal regional       58103
# 2      regional trabalho       57308
# 3      recurso ordinário       49591
# 4       justiça trabalho       42640
# ..                   ...         ...
# 25                13 467       26094
# 26     acórdão cabeçalho       25748
# 27  região identificação       25210
# 28       terceira região       24564
# 29     trabalho terceira       24531
#
# [30 rows x 2 columns]

# %%
trace = go.Bar(x=df4["INTEIRO_TEOR"], y=df4["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos trigramas mais usadas antes de remover stop words

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(df['INTEIRO_TEOR'], 20)
df5 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df5
# Out:
#                INTEIRO_TEOR  QUANTIDADE
# 0      regional do trabalho       57239
# 1            do trabalho da       55411
# 2      tribunal regional do       55408
# 3       justiça do trabalho       42622
# 4    embargos de declaração       35975
# ..                      ...         ...
# 15      público do trabalho       26029
# 16    ministério público do       26025
# 17          de horas extras       25929
# 18     acórdão cabeçalho do       25748
# 19  3ª região identificação       25210
#
# [20 rows x 2 columns]

# %%
trace = go.Bar(x=df5["INTEIRO_TEOR"], y=df5["QUANTIDADE"])
iplot({"data":[trace]})

# %% [markdown]
# ## Distribuição dos trigramas mais usadas depois de remover stop words

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer( stop_words = frozenset( stopwords ), ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(df['INTEIRO_TEOR'], 20)
df6 = pd.DataFrame(common_words, columns = ['INTEIRO_TEOR' , 'QUANTIDADE'])
df6
# Out:
#                     INTEIRO_TEOR  QUANTIDADE
# 0     tribunal regional trabalho       55399
# 1             trabalho 3ª região       29748
# 2           regional trabalho 3ª       29650
# 3     trabalho tribunal regional       26655
# 4      justiça trabalho tribunal       26652
# ..                           ...         ...
# 15        terceira região sessão       21903
# 16       região sessão ordinária       19747
# 17          turma hoje realizada       19514
# 18  recurso ordinário interposto       18622
# 19                    lei 13 467       17830
#
# [20 rows x 2 columns]

# %%
trace = go.Bar(x=df6["INTEIRO_TEOR"], y=df6["QUANTIDADE"])
iplot({"data":[trace]})
